# %% [markdown]
# ## Table of Contents
# * [برنامه نویسی ماژولار](#chapter1)
#     * [Script اسکریپت](#section_1_1)
#     * [Module ماژول](#section_1_2)
#     * [پکیج](#section_1_3)
#     * [library کتابخانه](#section_1_4)
#     * [فریمورک](#section_1_5)
# * [ساخت و استفاده از ماژول](#chapter2)
#     * [ساختار پروژه ها در پایتون](#section_2_1)
#     * [ساخت و استفاده از ماژول ها](#section_2_2)
#     * [ساخت و استفاده از پکیج ها](#section_2_3)
# * [تکمیلی](#chapter3)
#     * [ورژن های پایتون و path](#section_3_1)
#     * [سیستم مدیریت بسته pip و PyPi](#section_3_2)
#     * [محیط مجازی venv, virtualenv](#section_3_3)

# %% [markdown]
# # برنامه نویسی ماژولار <a class="anchor" id="chapter1"></a>

# %% [markdown]
#  در یک پروژه بزرگ قسمت های مختلف آن به بخش های کوچک تر تقسیم شده و در انتها این بخش های کوچک به عنوان ماژول ها در کنار یکدیگر پروژه اصلی را تشکیل می دهند

# %%
# برنامه نویسی ماژولار
# ساده تر بودن حل و توسعه یک بخش کوچکتر
# قابلیت نگهداری و ترمیم برنامه چرا که تاثیر ماژول ها بر یکدیگر کمتر است
# قابلیت استفاده مجدد
# هر ماژول فضای نام مخصوص خود دارد و لذا تداخل و تعارض پیش نمی آید

# %% [markdown]
# توابع، ماژول ها و پکیج ها هدفشان ایجاد ساختاری جهت برنامه نویسی ماژولار

# %% [markdown]
# ## Script اسکریپت  <a class="anchor" id="section_1_1"></a>

# %% [markdown]
# فایلهای با فرمت .پای که دستورات در آن نوشته شده و وظایف خاصی انجام می دهند اسکریپت گفته می شود. آنها نقطه شروع برنامه هستند و در آن ماژول ها فراخوانی میشوند

# %% [markdown]
# ## Module ماژول  <a class="anchor" id="section_1_2"></a>

# %% [markdown]
# ماژول نیز فایل با فرمت .پای هست که قرار نیست خودش اجرا شود بلکه توسط اسکریپت ها ایمپورت و مورد استفاده قرار میگیرد. معمولا شامل تعریف توابع و کلاس ها هستند

# %%
import random
import math
import functools

# %% [markdown]
# بطور کلی در جامعه مهندسی تفاوت اندکی بین ماژول و اسکریپت هست و به جای هم به کار میروند

# %% [markdown]
# ## پکیج  <a class="anchor" id="section_1_3"></a>

# %% [markdown]
# اجتماع ماژول های مرتبط با هم که در یک دایرکتوری قرار دارند.

# %%
# برای اینکه پوشه شامل ماژول ها به پکیج تبدیل شود لازم هست در آن پوشه یک ماژول دیگر با نام
# __init__.py
# ساخته شود

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# می توان داخل پکیچ پکیج داشت

# %%
# نحوه استفاده از پکیج ها
# import my_pakage.mod1.func1(arg)

# %% [markdown]
# ![Screenshot_20221104_102047.png](attachment:Screenshot_20221104_102047.png)

# %% [markdown]
# ## library کتابخانه  <a class="anchor" id="section_1_4"></a>

# %% [markdown]
# در پایتون خیلی مصطلح نیست ولی به مجموعه چند پکیچ یک لایبرری یا کتابخانه گفته میشود

# %%
# matplotlib
# pycake

# %% [markdown]
# دو نوع ماژول هستند : 1.ماژول خالص که همان ماژول های .پای هستند. 2. ماژول اکستنشن که با زبان دیگری نوشته شدند.

# %% [markdown]
# ## فریمورک  <a class="anchor" id="section_1_5"></a>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# چارچوب کلی برای تنظیم دایرکتوری ماژول ها و اسکریپت ها و نامگذاری آنها

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Django یک فریمورک است

# %% [markdown]
# # ساخت و استفاده از ماژول  <a class="anchor" id="chapter2"></a>

# %% [markdown]
# ## ساختار پروژه ها در پایتون <a class="anchor" id="section_2_1"></a>

# %% [markdown]
# یک استاندارد کلی برای فایلهای پروژه های پایتون هست که برای انتشار پروژه نیاز هست در نظر داشته باشیم

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# setup.cfg
# setup.py
# برای پیکربندی پروژه استفاده میشه
# تابع آن کپی و لازم هست یکسری آرگومان ها تنظیم شوند

# %%
# README.rst
# الزامی برای توصیف پروژه
# پسوند ار اس تی باشد چرا که از یک زبان نشانه گذاری برای آن استفاده میشه

# %%
# MANIFEST.in
# برای معرفی فایل های غیر پایتونی

# %%
# requirements.txt
# پیشنیازهای پروژه اعم از نسخه پایتون مورد استفاده

# %%
# LICENSE
# لایسنس انتشار پروژه شما
# معمولا از پروژه های اپن سورس کپی می شود

# %%
# پوشه docs
# شمال راهنماها، توضیحات، نکات و غیره

# %%
# پوشه tests
# تست های انجام گرفته روی پروژه

# %% [markdown]
# ## ساخت و استفاده از ماژول ها <a class="anchor" id="section_2_2"></a>

# %% [markdown]
# سه حالت مواجهه با ماژول ها و پکیج ها وجود دارد: یک بیلت-این هستند با ایمپورت وارد می شوند مانند رندوم. دوم ماژولها و کتابخانه های سایر برنامه نویسان باشند مثل نامپای لازم هست با پیپ نصب شود. سوم استفاده از ماژول های اختصاصی خودمان

# %%
# نصب ماژول ها و پکیج ها
# در کامندلاین سی ام دی
# در ترمینال پایتون
# در ژوپیتر لازم هست در یک بلاک باشد

# %%
pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# در پایچارم لازم هست محیط مجازی در نظر گرفته شود
#اگر میخواهیم با سی ام دی در محیط مجازی نصب کنیم
# لازم است ابتدا با به دایرکتوری آن برویم
# با cd

# %%
# استفاده از ماژول های اختصاصی
# لازم هست در دایرکتور پروژه باشد
import numpy
print(numpy)
# Out:
# <module 'numpy' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\numpy\\__init__.py'>

# %%
# نام اختصار
from random import randrange as rd
rd(25,30)
# Out:
# 25

# %%
# برای استفاده از توابع ماژول ها و پکیج ها لازم است با توجه به ترتیب از نقطه استفاده کرد
import random
random.randrange(29,31)
# Out:
# 30

# %%
# با ایمپورت فقط نام و آدرس ماژول وارد می شود و توابع وارد نمیشوند
# برای وارد کردن تابع از ماژول غیر از اختاصر و فرام
# می توان آن را با با عنوان یک شیء جدید اسکریپت استفاده کرد
import random
f = random.randrange  # بدون پرانتز
f(12,56)
# Out:
# 42

# %%
# دستور ایمپورت فقط یک بار اتفاق می افتد
# و اگر چند بار بنویسم اتفاقی نمیافته
# این موضوع وقتی که اسکریپت ایمپورت میکنیم اهمیت میابد

# %%
# میتوان متغیر های ماژول ها را تغییر داد
import math
math.pi = 2
math.pi
# Out:
# 2

# %%
import importlib

# %%
# برای ریلود کردن ماژول ها:
print(math.pi)
import importlib
importlib.reload(math)
print(math.pi)  # ?!
# Out:
# 2
# 2

# %%
# ماژول ها میتوانند شامل متغیر ها و کلاس ها باشد
import math
print(math.pi)
print(type(math.pi))
# پایتون چیزی به نام ثابت ندارد
# Out:
# 2
# <class 'int'>

# %%
# ایمپورت فقط برای ماژول ها است
# نمیتوان پکیچی ایمپورت کرد و تصور کرد تمام ماژول ها ایمپورت میشن

# %%
# برای وارد کردن فقط اشیاء از یک ماژول می توان از فرام استفاده کرد
from math import pi
pi
# Out:
# 2

# %%
# با فرام می توان چند شیء را اضافه کرد
from math import pi, cos, sin, log

# %%
# اگر میخواهیم تمام اشیاء یک ماژول ایمپورت شود
from math import *

# %%
# در استفاده از فرام دیگر خود ماژول شناخته شده نیست

# %%
# ماژول ها میتوانند متغیر مخفی داشته باشند
# در این صورت با * ایمپورت نمی شوند
_age = 5  # آندراسکور باعث مخفی شدن متغیر در ماژول می شود
# فقط با اشاره مستقیم می توان آن را وارد کرد

# %% [markdown]
# ماژول ها میتوانند طوری تنظیم شوند که اگر مستقل اجرا شوند دستوراتشان اجرا شود و اگر ایمپورت شوند دستوری از آنها اجرا نشود و فقط توابع و اشیا ایمپورت شوند

# %%
# __name__
# در اجرای مستقل خود ماژول 
# __main__
# را بر میگرداند
# و درصورت ایمپورت ماژول نام ماژول را

# %%
def func1(arg):
    print(arg)
    return

var1 = 45
var2 = 46

#---------------  # کافی است دستورات به شکل زیر وارد شوند
if __name__ == "__main__":
    func1(var1)
# Out:
# 45

# %%
# دایرکتور ماژول ها
# ماژول ها یک از مسیر پیشفرض نصب پایچارم ایمپورت می شوند
# دوم یا از دایرکتوری پروژه یا اسکریپت ایمپورت می شود

# %%
import sys

for i in sys.path:
    print(i)
    
# مسیر های زیر برای پایتون شناخته است و می توان از آنها ایمپورت کرد
# Out:
# C:\Users\hosbe\Documents
# C:\ProgramData\Anaconda3\python39.zip
# C:\ProgramData\Anaconda3\DLLs
# C:\ProgramData\Anaconda3\lib
# C:\ProgramData\Anaconda3
#
# C:\Users\hosbe\AppData\Roaming\Python\Python39\site-packages
# C:\ProgramData\Anaconda3\lib\site-packages
# C:\ProgramData\Anaconda3\lib\site-packages\win32
# C:\ProgramData\Anaconda3\lib\site-packages\win32\lib
# C:\ProgramData\Anaconda3\lib\site-packages\Pythonwin

# %%
import random
print(random)  # مسیر ماژول رندوم
# Out:
# <module 'random' from 'C:\\ProgramData\\Anaconda3\\lib\\random.py'>

# %%
# اضافه کردن دایرکتوری با کد
import sys
sys.path.append(r"G:\Ali") 
for i in sys.path:
    print(i)
# Out:
# C:\Users\hosbe\Documents
# C:\ProgramData\Anaconda3\python39.zip
# C:\ProgramData\Anaconda3\DLLs
# C:\ProgramData\Anaconda3\lib
# C:\ProgramData\Anaconda3
#
# C:\Users\hosbe\AppData\Roaming\Python\Python39\site-packages
# C:\ProgramData\Anaconda3\lib\site-packages
# C:\ProgramData\Anaconda3\lib\site-packages\win32
# C:\ProgramData\Anaconda3\lib\site-packages\win32\lib
# C:\ProgramData\Anaconda3\lib\site-packages\Pythonwin
# G:\Ali

# %% [markdown]
# در دایرکتوری پروژه یک __pycache__
# هست که ماژول های ایمپورت شده بصورت کامپایل شده در آن قرار می گیرند

# %%
# .pyc پسوند فایل های کامپایل شده پایتون هستند

# %%
# روش دیگر مشاهده مسیر ماژول
print(random.__file__)
# Out:
# C:\ProgramData\Anaconda3\lib\random.py

# %% [markdown]
# ## ساخت و استفاده از پکیچ ها <a class="anchor" id="section_2_3"></a>

# %%
# برای اینکه پوشه شامل ماژول ها به پکیج تبدیل شود 
# لازم هست در آن پوشه یک ماژول دیگر با نام
# __init__.py
# ساخته شود

# %% [markdown]
# ماژول خالی اینیت.پای الزامی نیست و حتی اگر نباشد میتوان از آن پوش به عنوان پکیج استفاده کرد ولی بهتر است باشد

# %%
# در صورت ایمپورت پکیج اگر در اینیت.پای دستوری باشد آن نیز اجرا میشود

# %%
# پکیج ها می توانند شامل پکیج نیز باشند

# %%
# در استفاده از فرام در نهایت لازم هست یا صفت(شیء) ایمپورت شود یا ماژول

# %%
# با فرام * می توان تمام صفت ها(شیء) های یک ماژول را ایمپورت کرد
from math import *
# print(globals())

# %%
# برای تعیین مواردی که با * ایمپورت می شوند در ماژول خود
__all__ = ["pow", "pi"]  # نوشت اسم اشیاء

# %%
# میتوان از فرام * برای ماژول های داخل پکیج نیز استفاده کرد
# در اینصورت برای مشخص کردن ماژول ها و __آل
# لازم هست __آل__ را در اینیت.پای

# %%
# در ماژول می توان ماژول دیگر را ایمپورت کرد
# دایرکتوری باید ذکر شود

# %%
# اگر آن ماژول نیز ایمپورت می شود
# و بخواهیم ماژول دیگری در آن ایمپورت کنیم
# یا دایرکتوری باید ذکر شود
# یا اگر در یک دایرکتوری هستند
# from . mod2 import func
# . در واقع به معنی پکیج پدر هست
# میتوان .. استفاده کرد به معنی دو تا پدر عقب هست

# %%
# ماژول ها می توانند داک اتسرینگ داشته باشند
"""my module"""

# help تمام جزئیات ماژول را نشان می دهد
# Out:
# 'my module'

# %% [markdown]
# # تکمیلی  <a class="anchor" id="chapter3"></a>

# %% [markdown]
# ## ورژن های پایتون و path <a class="anchor" id="section_3_1"></a>

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# اگر در هنگام نصب اد تو پث نزده باشید از این قسمت می توانید پث پایتون و اسکریپت آن را به کامپیوتر اضافه کنید

# %% [markdown]
# توجه شود که اولویت با متغیر های سیستمی است و بعد از آن در متغیر های کاربر هدکدام که بالاتر باشد

# %% [markdown]
# در سی ام دی می توان نسخه های مختلف پایتون که روی سیستم هستند را اجرا کرد. یک با سی دی و رفتن با دیرکتوری نسخه و دو با پای

# %% [raw]
# in cmd:
# py -3.8

# %% [markdown]
# ## سیستم مدیریت بسته pip و PyPi <a class="anchor" id="section_3_2"></a>

# %%
# pip
# package installer for python
# آرشیو در سایت PyPi.org
# لازم هست حتما آنلاین باشیم

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ABN==0.3.3  # نصب پکیج ورژن انتخابی

# %%
pip uninstall ABN  # حذف پکیج
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
python -m pip install -update pip  # آپدیت کردن پیپ
# Out:
#   Input In [58]
#     python -m pip install -update pip
#               ^
# SyntaxError: invalid syntax

# %%
pip list  # لیست کردن پکیج های نصب شده
# Out:
# Package                       Version
# ----------------------------- --------------------
# ABN                           0.3.3
# aiohttp                       3.8.1
# aiosignal                     1.2.0
# alabaster                     0.7.12
# anaconda-client               1.9.0
# anaconda-navigator            2.1.4
# anaconda-project              0.10.2
# anyio                         3.5.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.2
# astroid                       2.6.6
# astropy                       5.0.4
# asttokens                     2.0.5
# async-timeout                 4.0.1
# atomicwrites                  1.4.0
# attrs                         21.4.0
# Automat                       20.2.0
# autopep8                      1.6.0
# Babel                         2.9.1
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# ...

# %%
pip freeze > reqirements.txt  # ذخیره لیست پکیج ها
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## محیط مجازی venv, virtualenv  <a class="anchor" id="section_3_3"></a>

# %% [markdown]
# محیط مجازی شبیه سازی از نسخه های نصب شده پایتون و پکیج ها با انتقال پروژه منتقل می شود.

# %% [markdown]
# در نسخه های قدیمی لازم هست از طریق پیپ نصب کنیم virtualenv

# %%
pip install virtualenv
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# دایرکتور محیط مجازی
# ![image.png](attachment:image.png)

# %% [markdown]
# Lib شامل پکیج های از پیش نصب شده پایتون و یا پکیج های نصب شده برنامه نویس است

# %% [markdown]
# Scripts شامل اسکریپت ها وفایل های مفسر پایتون نسخه مورد نظر است

# %% [markdown]
# از سی ام دی می توان پکیج محیط مجازی را نصب کرد و بعد آن برای نسخه مورد نظر پایتون محیط مجازی ساخت

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# انتخاب ورژن پایتون
# ![image.png](attachment:image.png)

# %% [markdown]
# فعالسازی محیط مجازی
# ![image.png](attachment:image.png)

# %%
# activate.bat فعالسازی
# deactivate.bat غیرفعالسازی

# %%
# پایتون 3.3 به بعد
# ایجاد محیط مجازی از طریق ترمینال یا سی ام دی
# python -m venv desktop\enve1
