# %% [markdown]
# مفهوم شی گرایی

# %% [raw]
# اشیا یکسری چیزهایی هستند که یک ویژگی های خاص دارند یا وظیفه ایی خاصی انجام میدهند

# %% [raw]
# کلاس یک طرحیه که از روی آن میتونیم یکسری اشیا بسازیم که در آن طرح صفات و رفتار های آن شی که باید ساخته بشه نوشته میشه

# %% [markdown]
# که به رفتارها در کلاس گفته میشه
# method
#
# و به خصوصیات گفته میشه
# data type
#
# به نمونه ایی از آن کلاس ساخته میشه شی میگن یا یک نمونه از آن کلاس
# object - instans

# %% [raw]
# مرحله اول که آنالیز شی هست که چه رفتارهایی باید داشته باشیم چه کارهایی باید بکنیم
# OOA
# object orinted analyze
#
# آبجکت ها را نامگذاری بکنیم - ارتباط بین اشیا و به بگیم چطور این کار باید انجام شود
# OOD
# object orinted design
#
# بخش کد زنی
# یک شیوه کد زنی یا پارادایم
# یعنی تمایل به مدلسازی اشیا
# OOP
# object orinted programming

# %% [raw]
# با استفاده از کلاس ما یکسری تایپ های جدید را ایجاد میکنیم که رفتارها و صفات خاص خودش را دارد

# %% [raw]
# encapsulation
# کپسوله سازی
#
# data hiding
# پنهان سازی داده
#
# interface
# رابط

# %% [raw]
# کپسوله سازی
# دسته بندی متدها و اتریبیوت ها در کنار یکدیگر برای ایجاد یک شی
# سعی میکنیم پیچیدگی را کاهش دهیم

# %% [raw]
# پنهان سازی داده ها
# بعد از ایجاد یک کلاس لازم است به کاربر دسترسی به یکسری از داده ها را ندهیم مثلا برای
# تغییر داده ها
# تمرکز بر روی امنیت داده ها

# %%
کپسوله سازی یک فرآیند جامع تر نسبت به پنهان سازی داده ها است

# %% [raw]
# رابط
# اجازه ارتباط با شی را به ما میدهند مثل دکمه های تلویزیون
# مشخص میکنه که شی چه هدفی دارد و چکاری انجام میدهد
# در موقع نوشتن رابط به این تمرکز داریم که من به چه چیزی نیاز دارم
# پیاده سازی وجود ندارد فقثط تعریف میکنیم

# %% [raw]
# abstraction
# انتزاع
#
# انتزاع یعنی توجه به کلیات بدون توجه به جزییات
#
# یکسری مفاهیم کلی هستند مثل ماشین و حیوان و...
#
# مثلا وقتی میگیم ماشین نمیدونیم به چه نوع ماشینی اشاره میکند درسته یکسری ویژگی ها کلی دارند اما نوع آنرا نمیدانیم
#
# ماشین یک الگو است که به خودی خود وجود ندارد اما پراید که یک نمونه از آن است که وجود دارد
#
# در اینجا به ماشین - انتزاعی
# abstract
# و به پراید - واقعی
# concrete
#
# انتزاع میتواند سطح های مختلف داشته باشد و هرچقد کلی باشد انتزاعی تر است
#
# در اث بری یکسری کلاس ها ویژگی های کلی تر دارند که در همه اشیا که از کلاس های سطح پایین تر تولید میشوند وجود دارد و مشترک است
#
# وقتی از یک چیزی استفاده میکنیم بدون توجه به اتریبیوت ها و متد های آن در اصل از نگاه انتزاعی داریم که در نهایت به کلاس میرسیم
#
# درواقع کلاس یک دیگاه انتزاعی به یک شی است
#
# concrete class
# میتونن نمونه واقعی داشته باشند مثل پراید
#
# abstract class
# یکسریا کلی تر هستند و قابل پیاده سازی نیستند مثل ماشین
#
# ما یکسری متدها انتزاعی داریم
# abstract method
# در کلاس های سطح بالاتر تعریف میشه اما بدنه آن در کلاس های سطح پایین تر تعریف میشوند و شخصی سازی میشوند

# %% [raw]
# association
# رابطه
#
# aggregation
# تجمع
#
# composition
# ترکیب
#
# از پایین به بالا کلی تر هستند

# %% [raw]
# ترکیب
#
# برای پیاده سازی انتزاع از ارث بری و ترکیب استفاده میکنیم
#
# جمع آوری چند شی برای ایجاد یک شی جدید
#
# کلاس هایی که ارث بری میکنند از یک رابطه (هست یک) پیروی میکنند
# is-a
# پراید یک خودرو است
# ولی موتور پراید درسته از پراید ارث بری کرده و یک سری ویژگی های آن را دارد اما رابطه (هست یک ) ندارند موتور یک پراید نیست و به خودی خود یک شی مجزا است به این رابطه (دارد یک ) میگویند
# has-a
# به این ترکیب میگویند

# %% [raw]
# association
#
# این رابطه ضعیف است
#
# دوتا شی مختلف هستند که رابطه ضعیفی دارند
#
# نابودی یکی بر آن یکی تاثیری ندارد
#
# شی اول جزیی از شی دوم نیست میتونن مستقل از هم وجود داشته باشند
#
# مثل صاحب ماشین و ماشین یا دانشجو و استاد

# %% [raw]
# aggregation
#
# یک شی متعلق به شی دیگر است
#
# رابطه جزء به کل
#
# نابودی یکی بر دیگری تاثیری ندارد
#
# درسته جزیی از یک شی هستند و میتونن بطور مستقل باشند
#
# مثل وسایل تشکیل دهنده موبایل یا لاستیک و ماشین

# %%
composition

در اینجا تعلق وجود دارد

بصورت تنهایی معنایی ندارد

مثل تیکه های پازل یا مدرسه و اتاق هایش یا صفحات

# %% [raw]
# association >aggregation >composition

# %% [raw]
# inheritance
# وراثت

# %% [raw]
# وراثت
#
# یکسری متدها و اتریبیوت های کلاس بالایی را ارث می برد
#
# کلاس هایی که ارث بری میکنند از یک رابطه (هست یک) پیروی میکنند
# is-a
# پراید یک خودرو است
#
# اسم کلاسی که از آن ارث بری میکنیم
# parent class - base class - superclass
#
# کلاسی که ارث میبرد
# child class - derived class - subclass

# %% [markdown]
# انواع وراثت

# %% [markdown]
# ![Screenshot%20from%202023-07-24%2017-23-24.png](attachment:Screenshot%20from%202023-07-24%2017-23-24.png)

# %% [markdown]
# multiple
# زیاد توصیه نمیشود و استفاده نمیشود

# %%
مشکل الماس
یک زیر کلاس از دو ابر کلاس ارث بری میکند که آن دو از یکی ارثبری میکند که میتواند باعث مشکل شود

# %% [markdown]
# ![Screenshot%20from%202023-07-24%2017-47-30.png](attachment:Screenshot%20from%202023-07-24%2017-47-30.png)

# %% [markdown]
# MRO
# method resolution order
#
# ترتیب جستجو متدها و اتریبیوت ها
#
# الویت از پایین به بالا و از چپ به راست

# %% [markdown]
# همه کلاس ها از یک کلاس بنام آبجکت ارث بری میکنند

# %% [raw]
# polymorfism
# چند ریختی

# %% [raw]
# ممکنه برخی متدها و..  در کلاس های پایین تر که با اسم ثابت هستند اما به چند شکل متفاوت و رفتار متفاوت

# %% [raw]
# انواع مختلف دسته بندی پلی مورفیسم داریم
#
# انواع پلی مورفیسم

# %% [markdown]
# ![Screenshot%20from%202023-07-25%2011-19-48.png](attachment:Screenshot%20from%202023-07-25%2011-19-48.png)

# %% [markdown]
# subtype
# یک کلاس پایه وجود دارد که از آن ارث بری میکنند و یکسری متدها را override میکنند
# overide
#
# parametric
# یک نوع تابع داریم که بر اساس انواع مختلف کار خودش را انجام میدهد و رفتار یکسان
# template
#
# ad hoc
# یک تابع که با توجه به انواع مختلف رفتار های متفاوتی دارد
# method/operator overloading
#
# casting
# تبدیل نوع خودکار یک نوع بع نوع دیگر تبدیل میشود

# %% [raw]
# duck type
#
# خصوصیات و توابع شی نوع آنرا مشخص میکنند ن نوع و کلاس پدر یا اینترفیس
#
# مثلا تابع لن که هم در لیست و استرینگ و .. وجود دارد
# len
